# %% [markdown]
# # This is a visualization of usage over time fo the Toronto Bike data available through Open Data from the City of Toronto

# %% [markdown]
# ## Historical data can be found: https://open.toronto.ca/dataset/bike-share-toronto-ridership-data/

# %%
import pandas as pd
import requests
url = "https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/package_show"
params = { "id": "7e876c24-177c-4605-9cef-e50dd74c617f"}
package = requests.get(url, params = params).json()
print(package["result"])
# Out:
# {'license_title': 'Open Government Licence – Toronto', 'owner_unit': None, 'relationships_as_object': [], 'topics': 'Transportation', 'owner_email': 'customerservice@greenp.com', 'excerpt': 'Historical Bike Share Toronto ridership data. ', 'private': False, 'owner_division': 'Toronto Parking Authority', 'num_tags': 10, 'id': '7e876c24-177c-4605-9cef-e50dd74c617f', 'metadata_created': '2019-07-23T16:40:26.101562', 'refresh_rate': 'Monthly', 'title': 'Bike Share Toronto Ridership Data', 'license_url': 'https://open.toronto.ca/open-data-license/', 'state': 'active', 'information_url': 'https://parking.greenp.com/', 'license_id': 'open-government-licence-toronto', 'type': 'dataset', 'resources': [{'cache_last_updated': None, 'package_id': '7e876c24-177c-4605-9cef-e50dd74c617f', 'datastore_active': False, 'id': 'a1a0ee42-caf5-4395-abbc-58925c7434dd', 'size': 16625, 'format': 'XLSX', 'state': 'active', 'hash': '', 'description': '', 'is_preview': False, 'last_modified': '2019-07-23T16:40:46.986753', 'url_type': 'upload', 'mimetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'cache_url': None, 'extract_job': None, 'name': 'bikeshare-ridership-readme', 'created': '2019-07-23T16:40:47.062116', 'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/7e876c24-177c-4605-9cef-e50dd74c617f/resource/a1a0ee42-caf5-4395-abbc-58925c7434dd/download/bikeshare-ridership-readme.xlsx', 'mimetype_inner': None, 'position': 0, 'revision_id': '890aa1da-c8d0-4535-a719-14786ce56443', 'resource_type': None}, {'cache_last_updated': None, 'package_id': '7e876c24-177c-4605-9cef-e50dd74c617f', 'datastore_active': False, 'id': 'f931a332-09de-494b-afb0-c811c6ec4043', 'size': 1465200, 'format': 'XLSX', 'state': 'active', 'hash': '', 'description': '', 'is_preview': False, 'last_modified': '2019-07-23T16:40:27.121921', 'url_type': 'upload', 'mimetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'cache_url': None, 'extract_job': None, 'name': 'bikeshare-ridership-2014-q4-2015-q3', 'created': '2019-07-23T16:40:27.160810', 'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/7e876c24-177c-4605-9cef-e50dd74c617f/resource/f931a332-09de-494b-afb0-c811c6ec4043/download/bikeshare-ridership-2014-q4-2015-q3.xlsx', 'mimetype_inner': None, 'position': 1, 'revision_id': '890aa1da-c8d0-4535-a719-14786ce56443', 'resource_type': None}, {'cache_last_updated': None, 'package_id': '7e876c24-177c-4605-9cef-e50dd74c617f', 'datastore_active': False, 'id': '34c07f2a-abde-4d4f-9ee6-267a312f68e6', 'size': 18885816, 'format': 'XLSX', 'state': 'active', 'hash': '', 'description': '', 'is_preview': False, 'last_modified': '2019-07-23T16:40:32.718544', 'url_type': 'upload', 'mimetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'cache_url': None, 'extract_job': None, 'name': 'bikeshare-ridership-2016-q3', 'created': '2019-07-23T16:40:32.775321', 'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/7e876c24-177c-4605-9cef-e50dd74c617f/resource/34c07f2a-abde-4d4f-9ee6-267a312f68e6/download/bikeshare-ridership-2016-q3.xlsx', 'mimetype_inner': None, 'position': 2, 'revision_id': '890aa1da-c8d0-4535-a719-14786ce56443', 'resource_type': None}, {'cache_last_updated': None, 'package_id': '7e876c24-177c-4605-9cef-e50dd74c617f', 'datastore_active': False, 'id': 'fe1fc5c4-ba3e-480e-ad70-db5dc3097242', 'size': 9822853, 'format': 'XLSX', 'state': 'active', 'hash': '', 'description': '', 'is_preview': False, 'last_modified': '2019-07-23T16:40:37.645352', 'url_type': 'upload', 'mimetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'cache_url': None, 'extract_job': None, 'name': 'bikeshare-ridership-2016-q4', 'created': '2019-07-23T16:40:37.705489', 'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/7e876c24-177c-4605-9cef-e50dd74c617f/resource/fe1fc5c4-ba3e-480e-ad70-db5dc3097242/download/bikeshare-ridership-2016-q4.xlsx', 'mimetype_inner': None, 'position': 3,  ...
